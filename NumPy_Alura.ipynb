# %% [markdown]
# <a href="https://colab.research.google.com/github/kevirui/Alura-ONE-DataScience/blob/main/NumPy_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

url = 'https://gist.githubusercontent.com/ahcamachod/41b8a65c5e5b58125401deafb68af460/raw/f84320f69efa1cc3e86e1db054422cfa4869c63e/manzanas.csv'

# %%
datosManzana = np.loadtxt(url, delimiter=',', usecols = np.arange(1, 88, 1))

# %%
dimensionesDeMatriz = datosManzana.ndim

# %%
cantidadFilasxColumnas = datosManzana.shape

# %%
matrizTraspuesta = datosManzana.T

# %%
url = "https://gist.githubusercontent.com/ahcamachod/9be09de793dc3bf1e6c3d98eb4e5b1ef/raw/21b85572693200040e11284ef6dcfc3457ec8e11/citrus.csv"
datos = np.loadtxt(url, delimiter=',', usecols=np.arange(1, 6, 1), skiprows=1)
datos
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
fechas = matrizTraspuesta[:,0]

# %%
precios = matrizTraspuesta[:,1:]

# %%
import matplotlib.pyplot as plt

plt.plot(fechas, precios)

# %%
fechas = np.arange(1, 88, 1)

# %%
plt.plot(fechas, precios[:,0])

# %%
Moscu = precios[:,0]
Kaliningrado = precios[:,1]
Petersburgo = precios[:,2]
Krasnodar = precios[:,3]
Ekaterimburgo = precios[:,4]

# %%
plt.plot(fechas, Kaliningrado)

# %%
clientes = np.array([
    [1, 'Juan', 30, 'Calle A', 100, 'electrónicos'],
    [2, 'Maria', 25, 'Calle B', 200, 'moda'],
    [3, 'Pedro', 35, 'Calle C', 50, 'deportes']
])

clientes
# Out:
# array([['1', 'Juan', '30', 'Calle A', '100', 'electrónicos'],
#        ['2', 'Maria', '25', 'Calle B', '200', 'moda'],
#        ['3', 'Pedro', '35', 'Calle C', '50', 'deportes']], dtype='<U21')

# %%
clientes[:, 4:]
# Out:
# array([['100', 'electrónicos'],
#        ['200', 'moda'],
#        ['50', 'deportes']], dtype='<U21')

# %%
Moscu.shape
# Out:
# (87,)

# %%
moscu_1 = Moscu[0:12]
moscu_2 = Moscu[12:24]
moscu_3 = Moscu[24:36]
moscu_4 = Moscu[36:48]

# %%
plt.plot(np.arange(1, 13, 1), moscu_1)
plt.plot(np.arange(1, 13, 1), moscu_2)
plt.plot(np.arange(1, 13, 1), moscu_3)
plt.plot(np.arange(1, 13, 1), moscu_4)
plt.legend(['2013', '2014', '2015', '2016'])

# %%
# Averiguar si dos arreglos
np.array_equal(moscu_1, moscu_2)
# Out:
# False

# %%
# Averiguar si la diferencia entre los valores de dos arreglos son menores que el valor numerico dado por parametro
np.allclose(moscu_1,moscu_2, 5)
# Out:
# True

# %%
np.allclose(moscu_1,moscu_2, 0.1)
# Out:
# False

# %%
# Promedio de valores del arreglo
np.mean(Moscu)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(Kaliningrado)
# Out:
# np.float64(nan)

# %%
# Mostrar un arreglo sabiendo cuales de sus valores son NaN
np.isnan(Kaliningrado)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
# Mostrar cuantos valores NaN tengo en mis datos
np.sum(np.isnan(Kaliningrado))
# Out:
# np.int64(1)

# %%
Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado[5]) / 2
np.sum(np.isnan(Kaliningrado))
# Out:
# np.int64(0)

# %%
plt.plot(fechas, Kaliningrado)

# %%
# Precio promedio de las manzanas en una ciudad
np.mean(Kaliningrado)
# Out:
# np.float64(74.5506896551724)

# %%
# Naranja
diametro_naranja = datos[:5000, 0]
peso_naranja = datos[:5000, 1]

# Toronja
diametro_toronja = datos[5000:, 0]
peso_toronja = datos[5000:, 1]

plt.plot(diametro_naranja, peso_naranja)
plt.plot(diametro_toronja, peso_toronja)
plt.legend(['Naranja', 'Toronja'])

# %%
x = fechas
y = 0.5 * x + 78
y
# Out:
# array([ 78.5,  79. ,  79.5,  80. ,  80.5,  81. ,  81.5,  82. ,  82.5,
#         83. ,  83.5,  84. ,  84.5,  85. ,  85.5,  86. ,  86.5,  87. ,
#         87.5,  88. ,  88.5,  89. ,  89.5,  90. ,  90.5,  91. ,  91.5,
#         92. ,  92.5,  93. ,  93.5,  94. ,  94.5,  95. ,  95.5,  96. ,
#         96.5,  97. ,  97.5,  98. ,  98.5,  99. ,  99.5, 100. , 100.5,
#        101. , 101.5, 102. , 102.5, 103. , 103.5, 104. , 104.5, 105. ,
#        105.5, 106. , 106.5, 107. , 107.5, 108. , 108.5, 109. , 109.5,
#        110. , 110.5, 111. , 111.5, 112. , 112.5, 113. , 113.5, 114. ,
#        114.5, 115. , 115.5, 116. , 116.5, 117. , 117.5, 118. , 118.5,
#        119. , 119.5, 120. , 120.5, 121. , 121.5])

# %%
plt.plot(fechas, Moscu)
plt.plot(x, y)

# %%
Moscu - y
# Out:
# array([  1.22,   2.08,   0.18,  -0.2 ,   0.13,  -0.2 ,  -1.22,  -3.01,
#         -5.73,  -6.91,  -7.14,  -6.84,  -7.  ,  -5.97,  -5.22,  -5.95,
#         -8.39, -10.1 ,  -9.82, -11.95, -12.97, -15.61, -11.14,  -0.84,
#         14.93,  13.82,   9.65,   6.63,   7.46,   4.29,   5.14,  10.26,
#          8.13,   3.64,   1.67,   2.09,   6.57,  13.26,  13.34,  14.28,
#         12.6 ,  11.06,  14.2 ,  12.88,   1.58,  -5.46, -10.17, -12.01,
#        -11.06,  -9.49,  -9.9 , -10.22,  -5.59,  16.76,  24.1 ,  21.9 ,
#          8.05,  -5.12,  -8.41,  -4.65,  -1.92,  -1.  ,   5.45,  11.17,
#         11.98,  16.58,  20.39,  17.36,  -8.24, -19.55, -20.57, -17.85,
#        -15.4 , -12.  , -12.19, -12.99,  -9.13,  -0.09,   7.79,   5.94,
#         -5.47, -16.81, -21.67, -18.93, -17.06, -12.77, -11.22])

# %%
np.sum(np.power(Moscu - y, 2))
# Out:
# np.float64(10718.7341)

# %%
np.sqrt(np.sum(np.power(Moscu-y, 2)))
# Out:
# np.float64(103.53131941591394)

# %%
# Calcular la norma del vector o matriz Norma Euclídea (L2)
np.linalg.norm(Moscu - y)
# Out:
# np.float64(103.53131941591394)

# %%
# Copiar un arreglo
copiaDatos = np.copy(datos)
copiaDatos
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
n = np.size(Moscu)
y = Moscu
x = fechas

a = (n*np.sum(x*y)-np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - (np.sum(x))**2)

b = np.mean(y) - a*np.mean(x)

print(f'La pendiente es: {a}\nLa intersección es: {b}')
# Out:
# La pendiente es: 0.43520212145512926
# La intersección es: 79.64892274792834

# %%
y = a*x+b
y
# Out:
# array([ 80.08412487,  80.51932699,  80.95452911,  81.38973123,
#         81.82493336,  82.26013548,  82.6953376 ,  83.13053972,
#         83.56574184,  84.00094396,  84.43614608,  84.87134821,
#         85.30655033,  85.74175245,  86.17695457,  86.61215669,
#         87.04735881,  87.48256093,  87.91776306,  88.35296518,
#         88.7881673 ,  89.22336942,  89.65857154,  90.09377366,
#         90.52897578,  90.96417791,  91.39938003,  91.83458215,
#         92.26978427,  92.70498639,  93.14018851,  93.57539063,
#         94.01059276,  94.44579488,  94.880997  ,  95.31619912,
#         95.75140124,  96.18660336,  96.62180548,  97.05700761,
#         97.49220973,  97.92741185,  98.36261397,  98.79781609,
#         99.23301821,  99.66822033, 100.10342246, 100.53862458,
#        100.9738267 , 101.40902882, 101.84423094, 102.27943306,
#        102.71463519, 103.14983731, 103.58503943, 104.02024155,
#        104.45544367, 104.89064579, 105.32584791, 105.76105004,
# ...

# %%
np.linalg.norm(Moscu - y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(fechas, Moscu)
plt.plot(x, y)

# %%
plt.plot(fechas, Moscu)
plt.plot(x, y)

# Marcar en el grafico el valor de la manzana en el mes enero 2016
plt.plot(25, a*25+b, '*r')
plt.plot(75, a*75+b, '*r')

# %%
a*25+b
# Out:
# np.float64(90.52897578430657)

# %%
a*75+b
# Out:
# np.float64(112.28908185706302)

# %%
y = peso_naranja
x = diametro_naranja
n = np.size(x)

a = (n*np.sum(x*y)-np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - (np.sum(x))**2)

b = np.mean(y) - a*np.mean(x)

print(f'La pendiente es: {a}\nLa intersección es: {b}')
# Out:
# La pendiente es: 14.7997452319846
# La intersección es: 27.38560381218413

# %%
y = a*x+b
y
# Out:
# array([ 71.1928497 ,  85.25260767,  92.80047774, ..., 213.12240647,
#        216.08235552, 217.85832495])

# %%
plt.plot(diametro_naranja, peso_naranja)
plt.plot(x, y)

# %%
y = peso_toronja
x = diametro_toronja
n = np.size(x)

a = (n*np.sum(x*y)-np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - (np.sum(x))**2)

b = np.mean(y) - a*np.mean(x)

y = a*x+b

plt.plot(diametro_toronja, peso_toronja)
plt.plot(x, y)

# %%
# Generar numeros semi-aleatorios (desde, hasta, cuantos)
a = np.random.uniform(0.1, 0.5, 5)
a
# Out:
# array([0.36465861, 0.28763442, 0.36442761, 0.36290218, 0.45919537])

# %%
# Establece un estado de aleatoriedad
np.random.seed(99)

norma = np.array([])

for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscu - (pendientes[i]*x + b)))

# %%
np.savetxt('/content/Datosguardados/numpy/norma.csv', datos, delimiter=',')

# %%
norma = np.array([])
np.random.seed(84)
coeficientes_angulares = np.random.uniform(0.0, 30.0, 100)

for i in range(100):
  norma = np.append(norma, np.linalg.norm(peso_naranja - (coeficientes_angulares[i]*diametro_naranja + b)))

norma
# Out:
# array([ 4507.07277531,  1519.71444905,  1058.18105189,  6136.08231447,
#        12696.03964357,  2987.55352278,  2223.75307783,   822.87163731,
#         2357.61991976,  2979.8551131 ,   546.61865533,  3731.48295644,
#        12276.49974075,   553.77640665,  6558.38153828,  4457.46108619,
#        10824.54998722, 10417.4627442 , 11795.88180211,  3430.88343936,
#         5859.92827347,  2135.74532813,  3999.9477758 , 12801.76842802,
#         1286.00921108,  9961.50020377,  6309.73218662,  1596.96335007,
#        12483.90138126,  2847.87711964,  4775.27567012,   715.55933024,
#          650.57771401,   891.60711834,  2715.6497948 ,  9621.88269983,
#         2444.12587295,  3786.09982043,   892.08309555,  1851.72138554,
#         2706.80840791,  7191.11062873, 12777.91512911,   562.21612112,
#         5009.50925289,  3171.43946665,  4555.39137486,  2502.01219263,
#         2616.75901101,  1638.62906833,  4252.16948789,  6070.14527104,
# ...
